# %%
import glob
import re
import pandas as pd
import matplotlib.pyplot as plt

# %%
varCpu=None
varPlatform=None
varCudaversion=None
varGpuram=None
varGpu=None
varRam=None
varRun = None

mydict={}
myList=[]

# %%
def readInferAvgtime(line):
    pattern = "\d{1,2}\.\d{1,2} \- inference"
    result = re.match(pattern, line)
    if (result):
        varInference=line[18:].strip()
        print("For line '{0}', matched '{1}'\n{2}\n".format(line,pattern,varInference))
        runDetails=varInference.split(":")[0]
        time=varInference.split(":")[1].split("±")[0]
        mydict[str(varRun+" Inference, " + runDetails)]=float(time)

def readTrainAvgtime(line):
    pattern = "\d{1,2}\.\d{1,2} \- training"
    result = re.match(pattern, line)
    if (result):
        varTraining=line[18:].strip()
        print("For line '{0}', matched '{1}'\n{2}\n".format(line,pattern,varTraining))
        runDetails=varTraining.split(":")[0]
        time=varTraining.split(":")[1].split("±")[0]
        mydict[str(varRun+" Training, " + runDetails)]=float(time)

def readRunname(line):
    pattern = "\d{1,2}\/\d{2}\."
    result = re.match(pattern, line)
    if (result):
        global varRun
        varRun = line[6:].strip()
        print("For line '{0}', matched '{1}'\n{2}\n".format(line,pattern,varRun))

def readScores(line):
    pattern = "Device Inference Score\:"
    result = re.match(pattern, line)
    if (result):
        varInferScore = line[23:].strip()
        print("For line '{0}', matched '{1}'\n{2}\n".format(line,pattern,varInferScore))
        mydict["Inference Score"]=float(varInferScore)

    result=None
    pattern = "Device Training Score\:"
    result = re.match(pattern, line)
    if (result):
        varTrainScore = line[23:].strip()
        print("For line '{0}', matched '{1}'\n{2}\n".format(line,pattern,varTrainScore))
        mydict["Training Score"]=float(varTrainScore)

    result=None
    pattern = "Device AI Score\:"
    result = re.match(pattern, line)
    if (result):
        varAIScore = line[16:].strip()
        print("For line '{0}', matched '{1}'\n{2}\n".format(line,pattern,varAIScore))
        mydict["AI Score"]=float(varAIScore)
        

def readCudaversion(line):
    pattern = "\*  CUDA Version\:(.*)"
    result = re.match(pattern, line)
    if (result):
        global varCudaversion
        varCudaversion=line[17:].strip()
        print("For line '{0}', matched '{1}'\n{2}\n".format(line,pattern,varCudaversion))
        mydict["CUDA"] = varCudaversion

def readGpuram(line):
    pattern = "\*  GPU RAM\:(.*)"
    result = re.match(pattern, line)
    if (result):
        global varGpuram
        varGpuram=line[11:].strip()
        print("For line '{0}', matched '{1}'\n{2}\n".format(line,pattern,varGpuram))
        mydict["GPU_RAM"] = varGpuram

def readCpu(line):
    pattern = "\*  CPU\:(.*)"
    result = re.match(pattern, line)
    if (result):
        global varCpu
        varCpu=line[7:].strip()
        print("For line '{0}', matched '{1}'\n{2}\n".format(line,pattern,varCpu))
        mydict["CPU_CORES"] = varCpu

def readGpu(line):
    pattern = "\*  GPU/0\:(.*)"
    result = re.match(pattern, line)
    if (result):
        global varGpu
        varGpu=line[10:].strip()
        print("For line '{0}', matched '{1}'\n{2}\n".format(line,pattern,varGpu))
        mydict["GPU"] = varGpu

def readRam(line):
    pattern = "\*  CPU RAM\:(.*)"
    result = re.match(pattern, line)
    if (result):
        global varRam
        varRam=line[12:].strip()
        print("For line '{0}', matched '{1}'\n{2}\n".format(line,pattern,varRam))
        mydict["RAM"] = varRam

def readPlatform(line):
    pattern = "\*  Platform\:(.*)"
    result = re.match(pattern, line)
    if (result):
        global varPlatform
        varPlatform=line[13:].strip()
        print("For line '{0}', matched '{1}'\n{2}\n".format(line,pattern,varPlatform))
        mydict["PLATFORM"] = varPlatform

# %%
for name in glob.glob("*.log"):
    varCpu=None
    varPlatform=None
    varCudaversion=None
    varGpuram=None
    varGpu=None
    varRam=None
    varRun = None
    print("\n\nFilename: {0}".format(name))
    mydict["System"]=name
    with open(name) as fp:
        line=fp.readline()
        readCpu(line)
        readPlatform(line)
        readRam(line)
        readGpu(line)
        readGpuram(line)
        readCudaversion(line)
        while line:
            line = fp.readline()
            readCpu(line)
            readPlatform(line)
            readRam(line)
            readGpu(line)
            readGpuram(line)
            readCudaversion(line)
        fp.close()
    with open(name) as fp:
        line = fp.readline()
        readRunname(line)
        readInferAvgtime(line)
        while line:
            line = fp.readline()
            readRunname(line)
            readInferAvgtime(line)
        fp.close()
    with open(name) as fp:
        line = fp.readline()
        readRunname(line)
        readTrainAvgtime(line)
        while line:
            line = fp.readline()
            readRunname(line)
            readTrainAvgtime(line)
        fp.close()
    with open(name) as fp:
        line = fp.readline()
        readScores(line)
        while line:
            line = fp.readline()
            readScores(line)
        fp.close()
        

    myList.append(mydict)
    mydict={}

df=pd.DataFrame(myList)
df.head()
# Out:
# Filename: aibenchmark-cpu-crunchdata.log
# For line '*  Platform: Linux-4.15.0-117-generic-x86_64-with-Ubuntu-18.04-bionic
# ', matched '\*  Platform\:(.*)'
# Linux-4.15.0-117-generic-x86_64-with-Ubuntu-18.04-bionic
#
# For line '*  CPU: Intel Core Processor (Broadwell, no TSX, IBRS) 6-cores
# ', matched '\*  CPU\:(.*)'
# Intel Core Processor (Broadwell, no TSX, IBRS) 6-cores
#
# For line '*  CPU RAM: 21 GB
# ', matched '\*  CPU RAM\:(.*)'
# 21 GB
#
# For line '1/19. MobileNet-V2
# ', matched '\d{1,2}\/\d{2}\.'
# MobileNet-V2
#
# For line '1.1 - inference | batch=50, size=224x224: 669 ± 21 ms
# ', matched '\d{1,2}\.\d{1,2} \- inference'
# batch=50, size=224x224: 669 ± 21 ms
#
# For line '2/19. Inception-V3
# ', matched '\d{1,2}\/\d{2}\.'
# Inception-V3
#
# For line '2.1 - inference | batch=20, size=346x346: 1630 ± 16 ms
# ', matched '\d{1,2}\.\d{1,2} \- inference'
# batch=20, size=346x346: 1630 ± 16 ms
#
# For line '3/19. Inception-V4
# ', matched '\d{1,2}\/\d{2}\.'
# Inception-V4
#
# For line '3.1 - inference | batch=10, size=346x346: 1694 ± 17 ms
# ', matched '\d{1,2}\.\d{1,2} \- inference'
# batch=10, size=346x346: 1694 ± 17 ms
#
# For line '4/19. Inception-ResNet-V2
# ', matched '\d{1,2}\/\d{2}\.'
# Inception-ResNet-V2
#
# For line '4.1 - inference | batch=10, size=346x346: 1830 ± 13 ms
# ', matched '\d{1,2}\.\d{1,2} \- inference'
# batch=10, size=346x346: 1830 ± 13 ms
#
# For line '5/19. ResNet-V2-50
# ', matched '\d{1,2}\/\d{2}\.'
# ResNet-V2-50
#
# For line '5.1 - inference | batch=10, size=346x346: 1045 ± 7 ms
# ', matched '\d{1,2}\.\d{1,2} \- inference'
# batch=10, size=346x346: 1045 ± 7 ms
#
# For line '6/19. ResNet-V2-152
# ', matched '\d{1,2}\/\d{2}\.'
# ResNet-V2-152
#
# For line '6.1 - inference | batch=10, size=256x256: 1548 ± 10 ms
# ', matched '\d{1,2}\.\d{1,2} \- inference'
# batch=10, size=256x256: 1548 ± 10 ms
#
# For line '7/19. VGG-16
# ', matched '\d{1,2}\/\d{2}\.'
# VGG-16
#
# For line '7.1 - inference | batch=20, size=224x224: 3073 ± 16 ms
# ', matched '\d{1,2}\.\d{1,2} \- inference'
# batch=20, size=224x224: 3073 ± 16 ms
#
# For line '8/19. SRCNN 9-5-5
# ', matched '\d{1,2}\/\d{2}\.'
# SRCNN 9-5-5
#
# For line '8.1 - inference | batch=10, size=512x512: 2652 ± 17 ms
# ', matched '\d{1,2}\.\d{1,2} \- inference'
# batch=10, size=512x512: 2652 ± 17 ms
#
# For line '8.2 - inference | batch=1, size=1536x1536: 2384 ± 15 ms
# ', matched '\d{1,2}\.\d{1,2} \- inference'
# batch=1, size=1536x1536: 2384 ± 15 ms
#
# For line '9/19. VGG-19 Super-Res
# ', matched '\d{1,2}\/\d{2}\.'
# VGG-19 Super-Res
#
# For line '9.1 - inference | batch=10, size=256x256: 4956 ± 31 ms
# ', matched '\d{1,2}\.\d{1,2} \- inference'
# batch=10, size=256x256: 4956 ± 31 ms
#
# For line '9.2 - inference | batch=1, size=1024x1024: 7872 ± 37 ms
# ', matched '\d{1,2}\.\d{1,2} \- inference'
# batch=1, size=1024x1024: 7872 ± 37 ms
#
# For line '10/19. ResNet-SRGAN
# ', matched '\d{1,2}\/\d{2}\.'
# ResNet-SRGAN
#
# For line '10.1 - inference | batch=10, size=512x512: 4116 ± 23 ms
# ', matched '\d{1,2}\.\d{1,2} \- inference'
# batch=10, size=512x512: 4116 ± 23 ms
#
# For line '10.2 - inference | batch=1, size=1536x1536: 3730 ± 18 ms
# ', matched '\d{1,2}\.\d{1,2} \- inference'
# batch=1, size=1536x1536: 3730 ± 18 ms
#
# For line '11/19. ResNet-DPED
# ', matched '\d{1,2}\/\d{2}\.'
# ResNet-DPED
#
# For line '11.1 - inference | batch=10, size=256x256: 4622 ± 23 ms
# ', matched '\d{1,2}\.\d{1,2} \- inference'
# batch=10, size=256x256: 4622 ± 23 ms
#
# For line '11.2 - inference | batch=1, size=1024x1024: 7383 ± 39 ms
# ', matched '\d{1,2}\.\d{1,2} \- inference'
# batch=1, size=1024x1024: 7383 ± 39 ms
#
# For line '12/19. U-Net
# ', matched '\d{1,2}\/\d{2}\.'
# U-Net
#
# For line '12.1 - inference | batch=4, size=512x512: 9473 ± 39 ms
# ', matched '\d{1,2}\.\d{1,2} \- inference'
# batch=4, size=512x512: 9473 ± 39 ms
#
# For line '12.2 - inference | batch=1, size=1024x1024: 9624 ± 43 ms
# ', matched '\d{1,2}\.\d{1,2} \- inference'
# batch=1, size=1024x1024: 9624 ± 43 ms
#
# For line '13/19. Nvidia-SPADE
# ', matched '\d{1,2}\/\d{2}\.'
# Nvidia-SPADE
#
# For line '13.1 - inference | batch=5, size=128x128: 3542 ± 19 ms
# ', matched '\d{1,2}\.\d{1,2} \- inference'
# batch=5, size=128x128: 3542 ± 19 ms
#
# For line '14/19. ICNet
# ', matched '\d{1,2}\/\d{2}\.'
# ICNet
#
# For line '14.1 - inference | batch=5, size=1024x1536: 2515 ± 25 ms
# ', matched '\d{1,2}\.\d{1,2} \- inference'
# batch=5, size=1024x1536: 2515 ± 25 ms
#
# For line '15/19. PSPNet
# ', matched '\d{1,2}\/\d{2}\.'
# PSPNet
#
# For line '15.1 - inference | batch=5, size=720x720: 18287 ± 59 ms
# ', matched '\d{1,2}\.\d{1,2} \- inference'
# batch=5, size=720x720: 18287 ± 59 ms
#
# For line '16/19. DeepLab
# ', matched '\d{1,2}\/\d{2}\.'
# DeepLab
#
# For line '16.1 - inference | batch=2, size=512x512: 3964 ± 22 ms
# ', matched '\d{1,2}\.\d{1,2} \- inference'
# batch=2, size=512x512: 3964 ± 22 ms
#
# For line '17/19. Pixel-RNN
# ', matched '\d{1,2}\/\d{2}\.'
# Pixel-RNN
#
# For line '17.1 - inference | batch=50, size=64x64: 2895 ± 25 ms
# ', matched '\d{1,2}\.\d{1,2} \- inference'
# batch=50, size=64x64: 2895 ± 25 ms
#
# For line '18/19. LSTM-Sentiment
# ', matched '\d{1,2}\/\d{2}\.'
# LSTM-Sentiment
#
# For line '18.1 - inference | batch=100, size=1024x300: 8651 ± 152 ms
# ', matched '\d{1,2}\.\d{1,2} \- inference'
# batch=100, size=1024x300: 8651 ± 152 ms
#
# For line '19/19. GNMT-Translation
# ', matched '\d{1,2}\/\d{2}\.'
# GNMT-Translation
#
# For line '19.1 - inference | batch=1, size=1x20: 2190 ± 46 ms
# ', matched '\d{1,2}\.\d{1,2} \- inference'
# batch=1, size=1x20: 2190 ± 46 ms
#
# For line '1/19. MobileNet-V2
# ', matched '\d{1,2}\/\d{2}\.'
# MobileNet-V2
#
# For line '1.2 - training  | batch=50, size=224x224: 2815 ± 64 ms
# ', matched '\d{1,2}\.\d{1,2} \- training'
# batch=50, size=224x224: 2815 ± 64 ms
#
# For line '2/19. Inception-V3
# ', matched '\d{1,2}\/\d{2}\.'
# Inception-V3
#
# For line '2.2 - training  | batch=20, size=346x346: 7025 ± 60 ms
# ', matched '\d{1,2}\.\d{1,2} \- training'
# batch=20, size=346x346: 7025 ± 60 ms
#
# For line '3/19. Inception-V4
# ', matched '\d{1,2}\/\d{2}\.'
# Inception-V4
#
# For line '3.2 - training  | batch=10, size=346x346: 6645 ± 58 ms
# ', matched '\d{1,2}\.\d{1,2} \- training'
# batch=10, size=346x346: 6645 ± 58 ms
#
# For line '4/19. Inception-ResNet-V2
# ', matched '\d{1,2}\/\d{2}\.'
# Inception-ResNet-V2
#
# For line '4.2 - training  | batch=8, size=346x346: 5942 ± 43 ms
# ', matched '\d{1,2}\.\d{1,2} \- training'
# batch=8, size=346x346: 5942 ± 43 ms
#
# For line '5/19. ResNet-V2-50
# ', matched '\d{1,2}\/\d{2}\.'
# ResNet-V2-50
#
# For line '5.2 - training  | batch=10, size=346x346: 4207 ± 34 ms
# ', matched '\d{1,2}\.\d{1,2} \- training'
# batch=10, size=346x346: 4207 ± 34 ms
#
# For line '6/19. ResNet-V2-152
# ', matched '\d{1,2}\/\d{2}\.'
# ResNet-V2-152
#
# For line '6.2 - training  | batch=10, size=256x256: 6383 ± 50 ms
# ', matched '\d{1,2}\.\d{1,2} \- training'
# batch=10, size=256x256: 6383 ± 50 ms
#
# For line '7/19. VGG-16
# ', matched '\d{1,2}\/\d{2}\.'
# VGG-16
#
# For line '7.2 - training  | batch=2, size=224x224: 2290 ± 30 ms
# ', matched '\d{1,2}\.\d{1,2} \- training'
# batch=2, size=224x224: 2290 ± 30 ms
#
# For line '8/19. SRCNN 9-5-5
# ', matched '\d{1,2}\/\d{2}\.'
# SRCNN 9-5-5
#
# For line '8.3 - training  | batch=10, size=512x512: 17189 ± 180 ms
# ', matched '\d{1,2}\.\d{1,2} \- training'
# batch=10, size=512x512: 17189 ± 180 ms
#
# For line '9/19. VGG-19 Super-Res
# ', matched '\d{1,2}\/\d{2}\.'
# VGG-19 Super-Res
#
# For line '9.3 - training  | batch=10, size=224x224: 18894 ± 77 ms
# ', matched '\d{1,2}\.\d{1,2} \- training'
# batch=10, size=224x224: 18894 ± 77 ms
#
# For line '10/19. ResNet-SRGAN
# ', matched '\d{1,2}\/\d{2}\.'
# ResNet-SRGAN
#
# For line '10.3 - training  | batch=5, size=512x512: 8277 ± 61 ms
# ', matched '\d{1,2}\.\d{1,2} \- training'
# batch=5, size=512x512: 8277 ± 61 ms
#
# For line '11/19. ResNet-DPED
# ', matched '\d{1,2}\/\d{2}\.'
# ResNet-DPED
#
# For line '11.3 - training  | batch=15, size=128x128: 8537 ± 106 ms
# ', matched '\d{1,2}\.\d{1,2} \- training'
# batch=15, size=128x128: 8537 ± 106 ms
#
# For line '12/19. U-Net
# ', matched '\d{1,2}\/\d{2}\.'
# U-Net
#
# For line '12.3 - training  | batch=4, size=256x256: 10081 ± 61 ms
# ', matched '\d{1,2}\.\d{1,2} \- training'
# batch=4, size=256x256: 10081 ± 61 ms
#
# For line '13/19. Nvidia-SPADE
# ', matched '\d{1,2}\/\d{2}\.'
# Nvidia-SPADE
#
# For line '13.2 - training  | batch=1, size=128x128: 3624 ± 33 ms
# ', matched '\d{1,2}\.\d{1,2} \- training'
# batch=1, size=128x128: 3624 ± 33 ms
#
# For line '14/19. ICNet
# ', matched '\d{1,2}\/\d{2}\.'
# ICNet
#
# For line '14.2 - training  | batch=10, size=1024x1536: 6566 ± 47 ms
# ', matched '\d{1,2}\.\d{1,2} \- training'
# batch=10, size=1024x1536: 6566 ± 47 ms
#
# For line '15/19. PSPNet
# ', matched '\d{1,2}\/\d{2}\.'
# PSPNet
#
# For line '15.2 - training  | batch=1, size=512x512: 6713 ± 41 ms
# ', matched '\d{1,2}\.\d{1,2} \- training'
# batch=1, size=512x512: 6713 ± 41 ms
#
# For line '16/19. DeepLab
# ', matched '\d{1,2}\/\d{2}\.'
# DeepLab
#
# For line '16.2 - training  | batch=1, size=384x384: 4268 ± 27 ms
# ', matched '\d{1,2}\.\d{1,2} \- training'
# batch=1, size=384x384: 4268 ± 27 ms
#
# For line '17/19. Pixel-RNN
# ', matched '\d{1,2}\/\d{2}\.'
# Pixel-RNN
#
# For line '17.2 - training  | batch=10, size=64x64: 1978 ± 36 ms
# ', matched '\d{1,2}\.\d{1,2} \- training'
# batch=10, size=64x64: 1978 ± 36 ms
#
# For line '18/19. LSTM-Sentiment
# ', matched '\d{1,2}\/\d{2}\.'
# LSTM-Sentiment
#
# For line '18.2 - training  | batch=10, size=1024x300: 17398 ± 123 ms
# ', matched '\d{1,2}\.\d{1,2} \- training'
# batch=10, size=1024x300: 17398 ± 123 ms
#
# For line '19/19. GNMT-Translation
# ', matched '\d{1,2}\/\d{2}\.'
# GNMT-Translation
#
# For line 'Device Inference Score: 410
# ', matched 'Device Inference Score\:'
# 410
#
# For line 'Device Training Score: 470
# ', matched 'Device Training Score\:'
# 470
#
# For line 'Device AI Score: 880
# ', matched 'Device AI Score\:'
# 880
#
#
#
# Filename: aibenchmark-cpu-nutanix.log
# For line '*  Platform: Linux-5.3.0-28-generic-x86_64-with-Ubuntu-18.04-bionic
# ', matched '\*  Platform\:(.*)'
# Linux-5.3.0-28-generic-x86_64-with-Ubuntu-18.04-bionic
#
# For line '*  CPU: N/A
# ', matched '\*  CPU\:(.*)'
# N/A
#
# For line '*  CPU RAM: 63 GB
# ', matched '\*  CPU RAM\:(.*)'
# 63 GB
#
# For line '1/19. MobileNet-V2
# ', matched '\d{1,2}\/\d{2}\.'
# MobileNet-V2
#
# For line '1.1 - inference | batch=50, size=224x224: 370 ± 16 ms
# ', matched '\d{1,2}\.\d{1,2} \- inference'
# batch=50, size=224x224: 370 ± 16 ms
#
# For line '2/19. Inception-V3
# ', matched '\d{1,2}\/\d{2}\.'
# Inception-V3
#
# For line '2.1 - inference | batch=20, size=346x346: 691 ± 42 ms
# ', matched '\d{1,2}\.\d{1,2} \- inference'
# batch=20, size=346x346: 691 ± 42 ms
#
# For line '3/19. Inception-V4
# ', matched '\d{1,2}\/\d{2}\.'
# Inception-V4
#
# For line '3.1 - inference | batch=10, size=346x346: 686 ± 26 ms
# ', matched '\d{1,2}\.\d{1,2} \- inference'
# batch=10, size=346x346: 686 ± 26 ms
#
# For line '4/19. Inception-ResNet-V2
# ', matched '\d{1,2}\/\d{2}\.'
# Inception-ResNet-V2
#
# For line '4.1 - inference | batch=10, size=346x346: 768 ± 33 ms
# ', matched '\d{1,2}\.\d{1,2} \- inference'
# batch=10, size=346x346: 768 ± 33 ms
#
# For line '5/19. ResNet-V2-50
# ', matched '\d{1,2}\/\d{2}\.'
# ResNet-V2-50
#
# For line '5.1 - inference | batch=10, size=346x346: 495 ± 15 ms
# ', matched '\d{1,2}\.\d{1,2} \- inference'
# batch=10, size=346x346: 495 ± 15 ms
#
# For line '6/19. ResNet-V2-152
# ', matched '\d{1,2}\/\d{2}\.'
# ResNet-V2-152
#
# For line '6.1 - inference | batch=10, size=256x256: 653 ± 23 ms
# ', matched '\d{1,2}\.\d{1,2} \- inference'
# batch=10, size=256x256: 653 ± 23 ms
#
# For line '7/19. VGG-16
# ', matched '\d{1,2}\/\d{2}\.'
# VGG-16
#
# For line '7.1 - inference | batch=20, size=224x224: 1089 ± 46 ms
# ', matched '\d{1,2}\.\d{1,2} \- inference'
# batch=20, size=224x224: 1089 ± 46 ms
#
# For line '8/19. SRCNN 9-5-5
# ', matched '\d{1,2}\/\d{2}\.'
# SRCNN 9-5-5
#
# For line '8.1 - inference | batch=10, size=512x512: 1014 ± 45 ms
# ', matched '\d{1,2}\.\d{1,2} \- inference'
# batch=10, size=512x512: 1014 ± 45 ms
#
# For line '8.2 - inference | batch=1, size=1536x1536: 904 ± 29 ms
# ', matched '\d{1,2}\.\d{1,2} \- inference'
# batch=1, size=1536x1536: 904 ± 29 ms
#
# For line '9/19. VGG-19 Super-Res
# ', matched '\d{1,2}\/\d{2}\.'
# VGG-19 Super-Res
#
# For line '9.1 - inference | batch=10, size=256x256: 1915 ± 61 ms
# ', matched '\d{1,2}\.\d{1,2} \- inference'
# batch=10, size=256x256: 1915 ± 61 ms
#
# For line '9.2 - inference | batch=1, size=1024x1024: 2981 ± 83 ms
# ', matched '\d{1,2}\.\d{1,2} \- inference'
# batch=1, size=1024x1024: 2981 ± 83 ms
#
# For line '10/19. ResNet-SRGAN
# ', matched '\d{1,2}\/\d{2}\.'
# ResNet-SRGAN
#
# For line '10.1 - inference | batch=10, size=512x512: 2137 ± 74 ms
# ', matched '\d{1,2}\.\d{1,2} \- inference'
# batch=10, size=512x512: 2137 ± 74 ms
#
# For line '10.2 - inference | batch=1, size=1536x1536: 1950 ± 82 ms
# ', matched '\d{1,2}\.\d{1,2} \- inference'
# batch=1, size=1536x1536: 1950 ± 82 ms
#
# For line '11/19. ResNet-DPED
# ', matched '\d{1,2}\/\d{2}\.'
# ResNet-DPED
#
# For line '11.1 - inference | batch=10, size=256x256: 2188 ± 47 ms
# ', matched '\d{1,2}\.\d{1,2} \- inference'
# batch=10, size=256x256: 2188 ± 47 ms
#
# For line '11.2 - inference | batch=1, size=1024x1024: 3462 ± 62 ms
# ', matched '\d{1,2}\.\d{1,2} \- inference'
# batch=1, size=1024x1024: 3462 ± 62 ms
#
# For line '12/19. U-Net
# ', matched '\d{1,2}\/\d{2}\.'
# U-Net
#
# For line '12.1 - inference | batch=4, size=512x512: 4113 ± 63 ms
# ', matched '\d{1,2}\.\d{1,2} \- inference'
# batch=4, size=512x512: 4113 ± 63 ms
#
# For line '12.2 - inference | batch=1, size=1024x1024: 4265 ± 68 ms
# ', matched '\d{1,2}\.\d{1,2} \- inference'
# batch=1, size=1024x1024: 4265 ± 68 ms
#
# For line '13/19. Nvidia-SPADE
# ', matched '\d{1,2}\/\d{2}\.'
# Nvidia-SPADE
#
# For line '13.1 - inference | batch=5, size=128x128: 1270 ± 24 ms
# ', matched '\d{1,2}\.\d{1,2} \- inference'
# batch=5, size=128x128: 1270 ± 24 ms
#
# For line '14/19. ICNet
# ', matched '\d{1,2}\/\d{2}\.'
# ICNet
#
# For line '14.1 - inference | batch=5, size=1024x1536: 1889 ± 77 ms
# ', matched '\d{1,2}\.\d{1,2} \- inference'
# batch=5, size=1024x1536: 1889 ± 77 ms
#
# For line '15/19. PSPNet
# ', matched '\d{1,2}\/\d{2}\.'
# PSPNet
#
# For line '15.1 - inference | batch=5, size=720x720: 7307 ± 94 ms
# ', matched '\d{1,2}\.\d{1,2} \- inference'
# batch=5, size=720x720: 7307 ± 94 ms
#
# For line '16/19. DeepLab
# ', matched '\d{1,2}\/\d{2}\.'
# DeepLab
#
# For line '16.1 - inference | batch=2, size=512x512: 1796 ± 40 ms
# ', matched '\d{1,2}\.\d{1,2} \- inference'
# batch=2, size=512x512: 1796 ± 40 ms
#
# For line '17/19. Pixel-RNN
# ', matched '\d{1,2}\/\d{2}\.'
# Pixel-RNN
#
# For line '17.1 - inference | batch=50, size=64x64: 2281 ± 31 ms
# ', matched '\d{1,2}\.\d{1,2} \- inference'
# batch=50, size=64x64: 2281 ± 31 ms
#
# For line '18/19. LSTM-Sentiment
# ', matched '\d{1,2}\/\d{2}\.'
# LSTM-Sentiment
#
# For line '18.1 - inference | batch=100, size=1024x300: 4873 ± 56 ms
# ', matched '\d{1,2}\.\d{1,2} \- inference'
# batch=100, size=1024x300: 4873 ± 56 ms
#
# For line '19/19. GNMT-Translation
# ', matched '\d{1,2}\/\d{2}\.'
# GNMT-Translation
#
# For line '19.1 - inference | batch=1, size=1x20: 2326 ± 140 ms
# ', matched '\d{1,2}\.\d{1,2} \- inference'
# batch=1, size=1x20: 2326 ± 140 ms
#
# For line '1/19. MobileNet-V2
# ', matched '\d{1,2}\/\d{2}\.'
# MobileNet-V2
#
# For line '1.2 - training  | batch=50, size=224x224: 1668 ± 56 ms
# ', matched '\d{1,2}\.\d{1,2} \- training'
# batch=50, size=224x224: 1668 ± 56 ms
#
# For line '2/19. Inception-V3
# ', matched '\d{1,2}\/\d{2}\.'
# Inception-V3
#
# For line '2.2 - training  | batch=20, size=346x346: 3736 ± 91 ms
# ', matched '\d{1,2}\.\d{1,2} \- training'
# batch=20, size=346x346: 3736 ± 91 ms
#
# For line '3/19. Inception-V4
# ', matched '\d{1,2}\/\d{2}\.'
# Inception-V4
#
# For line '3.2 - training  | batch=10, size=346x346: 3161 ± 71 ms
# ', matched '\d{1,2}\.\d{1,2} \- training'
# batch=10, size=346x346: 3161 ± 71 ms
#
# For line '4/19. Inception-ResNet-V2
# ', matched '\d{1,2}\/\d{2}\.'
# Inception-ResNet-V2
#
# For line '4.2 - training  | batch=8, size=346x346: 2934 ± 73 ms
# ', matched '\d{1,2}\.\d{1,2} \- training'
# batch=8, size=346x346: 2934 ± 73 ms
#
# For line '5/19. ResNet-V2-50
# ', matched '\d{1,2}\/\d{2}\.'
# ResNet-V2-50
#
# For line '5.2 - training  | batch=10, size=346x346: 2302 ± 52 ms
# ', matched '\d{1,2}\.\d{1,2} \- training'
# batch=10, size=346x346: 2302 ± 52 ms
#
# For line '6/19. ResNet-V2-152
# ', matched '\d{1,2}\/\d{2}\.'
# ResNet-V2-152
#
# For line '6.2 - training  | batch=10, size=256x256: 3254 ± 98 ms
# ', matched '\d{1,2}\.\d{1,2} \- training'
# batch=10, size=256x256: 3254 ± 98 ms
#
# For line '7/19. VGG-16
# ', matched '\d{1,2}\/\d{2}\.'
# VGG-16
#
# For line '7.2 - training  | batch=2, size=224x224: 1734 ± 45 ms
# ', matched '\d{1,2}\.\d{1,2} \- training'
# batch=2, size=224x224: 1734 ± 45 ms
#
# For line '8/19. SRCNN 9-5-5
# ', matched '\d{1,2}\/\d{2}\.'
# SRCNN 9-5-5
#
# For line '8.3 - training  | batch=10, size=512x512: 13250 ± 189 ms
# ', matched '\d{1,2}\.\d{1,2} \- training'
# batch=10, size=512x512: 13250 ± 189 ms
#
# For line '9/19. VGG-19 Super-Res
# ', matched '\d{1,2}\/\d{2}\.'
# VGG-19 Super-Res
#
# For line '9.3 - training  | batch=10, size=224x224: 13843 ± 162 ms
# ', matched '\d{1,2}\.\d{1,2} \- training'
# batch=10, size=224x224: 13843 ± 162 ms
#
# For line '10/19. ResNet-SRGAN
# ', matched '\d{1,2}\/\d{2}\.'
# ResNet-SRGAN
#
# For line '10.3 - training  | batch=5, size=512x512: 5852 ± 88 ms
# ', matched '\d{1,2}\.\d{1,2} \- training'
# batch=5, size=512x512: 5852 ± 88 ms
#
# For line '11/19. ResNet-DPED
# ', matched '\d{1,2}\/\d{2}\.'
# ResNet-DPED
#
# For line '11.3 - training  | batch=15, size=128x128: 6305 ± 117 ms
# ', matched '\d{1,2}\.\d{1,2} \- training'
# batch=15, size=128x128: 6305 ± 117 ms
#
# For line '12/19. U-Net
# ', matched '\d{1,2}\/\d{2}\.'
# U-Net
#
# For line '12.3 - training  | batch=4, size=256x256: 6756 ± 168 ms
# ', matched '\d{1,2}\.\d{1,2} \- training'
# batch=4, size=256x256: 6756 ± 168 ms
#
# For line '13/19. Nvidia-SPADE
# ', matched '\d{1,2}\/\d{2}\.'
# Nvidia-SPADE
#
# For line '13.2 - training  | batch=1, size=128x128: 1630 ± 26 ms
# ', matched '\d{1,2}\.\d{1,2} \- training'
# batch=1, size=128x128: 1630 ± 26 ms
#
# For line '14/19. ICNet
# ', matched '\d{1,2}\/\d{2}\.'
# ICNet
#
# For line '14.2 - training  | batch=10, size=1024x1536: 5189 ± 164 ms
# ', matched '\d{1,2}\.\d{1,2} \- training'
# batch=10, size=1024x1536: 5189 ± 164 ms
#
# For line '15/19. PSPNet
# ', matched '\d{1,2}\/\d{2}\.'
# PSPNet
#
# For line '15.2 - training  | batch=1, size=512x512: 3495 ± 106 ms
# ', matched '\d{1,2}\.\d{1,2} \- training'
# batch=1, size=512x512: 3495 ± 106 ms
#
# For line '16/19. DeepLab
# ', matched '\d{1,2}\/\d{2}\.'
# DeepLab
#
# For line '16.2 - training  | batch=1, size=384x384: 2212 ± 41 ms
# ', matched '\d{1,2}\.\d{1,2} \- training'
# batch=1, size=384x384: 2212 ± 41 ms
#
# For line '17/19. Pixel-RNN
# ', matched '\d{1,2}\/\d{2}\.'
# Pixel-RNN
#
# For line '17.2 - training  | batch=10, size=64x64: 1795 ± 25 ms
# ', matched '\d{1,2}\.\d{1,2} \- training'
# batch=10, size=64x64: 1795 ± 25 ms
#
# For line '18/19. LSTM-Sentiment
# ', matched '\d{1,2}\/\d{2}\.'
# LSTM-Sentiment
#
# For line '18.2 - training  | batch=10, size=1024x300: 6093 ± 93 ms
# ', matched '\d{1,2}\.\d{1,2} \- training'
# batch=10, size=1024x300: 6093 ± 93 ms
#
# For line '19/19. GNMT-Translation
# ', matched '\d{1,2}\/\d{2}\.'
# GNMT-Translation
#
# For line 'Device Inference Score: 866
# ', matched 'Device Inference Score\:'
# 866
#
# For line 'Device Training Score: 786
# ', matched 'Device Training Score\:'
# 786
#
# For line 'Device AI Score: 1652
# ', matched 'Device AI Score\:'
# 1652
#
#
#
# Filename: aibenchmark-gpu-crunchdata.log
# For line '*  Platform: Linux-4.15.0-117-generic-x86_64-with-Ubuntu-18.04-bionic
# ', matched '\*  Platform\:(.*)'
# Linux-4.15.0-117-generic-x86_64-with-Ubuntu-18.04-bionic
#
# For line '*  CPU: Intel Core Processor (Broadwell, no TSX, IBRS) 6 cores
# ', matched '\*  CPU\:(.*)'
# Intel Core Processor (Broadwell, no TSX, IBRS) 6 cores
#
# For line '*  CPU RAM: 21 GB
# ', matched '\*  CPU RAM\:(.*)'
# 21 GB
#
# For line '*  GPU/0: Tesla V100-SXM2-16GB
# ', matched '\*  GPU/0\:(.*)'
# Tesla V100-SXM2-16GB
#
# For line '*  GPU RAM: 14.3 GB
# ', matched '\*  GPU RAM\:(.*)'
# 14.3 GB
#
# For line '*  CUDA Version: 10.2
# ', matched '\*  CUDA Version\:(.*)'
# 10.2
#
# For line '1/19. MobileNet-V2
# ', matched '\d{1,2}\/\d{2}\.'
# MobileNet-V2
#
# For line '1.1 - inference | batch=50, size=224x224: 42.7 ± 33.8 ms
# ', matched '\d{1,2}\.\d{1,2} \- inference'
# batch=50, size=224x224: 42.7 ± 33.8 ms
#
# For line '2/19. Inception-V3
# ', matched '\d{1,2}\/\d{2}\.'
# Inception-V3
#
# For line '2.1 - inference | batch=20, size=346x346: 55.6 ± 2.1 ms
# ', matched '\d{1,2}\.\d{1,2} \- inference'
# batch=20, size=346x346: 55.6 ± 2.1 ms
#
# For line '3/19. Inception-V4
# ', matched '\d{1,2}\/\d{2}\.'
# Inception-V4
#
# For line '3.1 - inference | batch=10, size=346x346: 48.5 ± 2.2 ms
# ', matched '\d{1,2}\.\d{1,2} \- inference'
# batch=10, size=346x346: 48.5 ± 2.2 ms
#
# For line '4/19. Inception-ResNet-V2
# ', matched '\d{1,2}\/\d{2}\.'
# Inception-ResNet-V2
#
# For line '4.1 - inference | batch=10, size=346x346: 60.9 ± 2.4 ms
# ', matched '\d{1,2}\.\d{1,2} \- inference'
# batch=10, size=346x346: 60.9 ± 2.4 ms
#
# For line '5/19. ResNet-V2-50
# ', matched '\d{1,2}\/\d{2}\.'
# ResNet-V2-50
#
# For line '5.1 - inference | batch=10, size=346x346: 33.5 ± 1.8 ms
# ', matched '\d{1,2}\.\d{1,2} \- inference'
# batch=10, size=346x346: 33.5 ± 1.8 ms
#
# For line '6/19. ResNet-V2-152
# ', matched '\d{1,2}\/\d{2}\.'
# ResNet-V2-152
#
# For line '6.1 - inference | batch=10, size=256x256: 37.9 ± 1.6 ms
# ', matched '\d{1,2}\.\d{1,2} \- inference'
# batch=10, size=256x256: 37.9 ± 1.6 ms
#
# For line '7/19. VGG-16
# ', matched '\d{1,2}\/\d{2}\.'
# VGG-16
#
# For line '7.1 - inference | batch=20, size=224x224: 59.5 ± 1.5 ms
# ', matched '\d{1,2}\.\d{1,2} \- inference'
# batch=20, size=224x224: 59.5 ± 1.5 ms
#
# For line '8/19. SRCNN 9-5-5
# ', matched '\d{1,2}\/\d{2}\.'
# SRCNN 9-5-5
#
# For line '8.1 - inference | batch=10, size=512x512: 66.9 ± 2.4 ms
# ', matched '\d{1,2}\.\d{1,2} \- inference'
# batch=10, size=512x512: 66.9 ± 2.4 ms
#
# For line '8.2 - inference | batch=1, size=1536x1536: 54.3 ± 1.4 ms
# ', matched '\d{1,2}\.\d{1,2} \- inference'
# batch=1, size=1536x1536: 54.3 ± 1.4 ms
#
# For line '9/19. VGG-19 Super-Res
# ', matched '\d{1,2}\/\d{2}\.'
# VGG-19 Super-Res
#
# For line '9.1 - inference | batch=10, size=256x256: 66.7 ± 1.2 ms
# ', matched '\d{1,2}\.\d{1,2} \- inference'
# batch=10, size=256x256: 66.7 ± 1.2 ms
#
# For line '9.2 - inference | batch=1, size=1024x1024: 95.0 ± 0.5 ms
# ', matched '\d{1,2}\.\d{1,2} \- inference'
# batch=1, size=1024x1024: 95.0 ± 0.5 ms
#
# For line '10/19. ResNet-SRGAN
# ', matched '\d{1,2}\/\d{2}\.'
# ResNet-SRGAN
#
# For line '10.1 - inference | batch=10, size=512x512: 78.1 ± 2.3 ms
# ', matched '\d{1,2}\.\d{1,2} \- inference'
# batch=10, size=512x512: 78.1 ± 2.3 ms
#
# For line '10.2 - inference | batch=1, size=1536x1536: 66.4 ± 2.3 ms
# ', matched '\d{1,2}\.\d{1,2} \- inference'
# batch=1, size=1536x1536: 66.4 ± 2.3 ms
#
# For line '11/19. ResNet-DPED
# ', matched '\d{1,2}\/\d{2}\.'
# ResNet-DPED
#
# For line '11.1 - inference | batch=10, size=256x256: 65.5 ± 0.8 ms
# ', matched '\d{1,2}\.\d{1,2} \- inference'
# batch=10, size=256x256: 65.5 ± 0.8 ms
#
# For line '11.2 - inference | batch=1, size=1024x1024: 126.2 ± 0.9 ms
# ', matched '\d{1,2}\.\d{1,2} \- inference'
# batch=1, size=1024x1024: 126.2 ± 0.9 ms
#
# For line '12/19. U-Net
# ', matched '\d{1,2}\/\d{2}\.'
# U-Net
#
# For line '12.1 - inference | batch=4, size=512x512: 121 ± 1 ms
# ', matched '\d{1,2}\.\d{1,2} \- inference'
# batch=4, size=512x512: 121 ± 1 ms
#
# For line '12.2 - inference | batch=1, size=1024x1024: 122 ± 1 ms
# ', matched '\d{1,2}\.\d{1,2} \- inference'
# batch=1, size=1024x1024: 122 ± 1 ms
#
# For line '13/19. Nvidia-SPADE
# ', matched '\d{1,2}\/\d{2}\.'
# Nvidia-SPADE
#
# For line '13.1 - inference | batch=5, size=128x128: 65.9 ± 2.3 ms
# ', matched '\d{1,2}\.\d{1,2} \- inference'
# batch=5, size=128x128: 65.9 ± 2.3 ms
#
# For line '14/19. ICNet
# ', matched '\d{1,2}\/\d{2}\.'
# ICNet
#
# For line '14.1 - inference | batch=5, size=1024x1536: 179 ± 4 ms
# ', matched '\d{1,2}\.\d{1,2} \- inference'
# batch=5, size=1024x1536: 179 ± 4 ms
#
# For line '15/19. PSPNet
# ', matched '\d{1,2}\/\d{2}\.'
# PSPNet
#
# For line '15.1 - inference | batch=5, size=720x720: 258 ± 5 ms
# ', matched '\d{1,2}\.\d{1,2} \- inference'
# batch=5, size=720x720: 258 ± 5 ms
#
# For line '16/19. DeepLab
# ', matched '\d{1,2}\/\d{2}\.'
# DeepLab
#
# For line '16.1 - inference | batch=2, size=512x512: 75.6 ± 1.5 ms
# ', matched '\d{1,2}\.\d{1,2} \- inference'
# batch=2, size=512x512: 75.6 ± 1.5 ms
# For line '17/19. Pixel-RNN
# ', matched '\d{1,2}\/\d{2}\.'
# Pixel-RNN
#
# For line '17.1 - inference | batch=50, size=64x64: 659 ± 18 ms
# ', matched '\d{1,2}\.\d{1,2} \- inference'
# batch=50, size=64x64: 659 ± 18 ms
#
# For line '18/19. LSTM-Sentiment
# ', matched '\d{1,2}\/\d{2}\.'
# LSTM-Sentiment
#
# For line '18.1 - inference | batch=100, size=1024x300: 667 ± 103 ms
# ', matched '\d{1,2}\.\d{1,2} \- inference'
# batch=100, size=1024x300: 667 ± 103 ms
#
# For line '19/19. GNMT-Translation
# ', matched '\d{1,2}\/\d{2}\.'
# GNMT-Translation
#
# For line '19.1 - inference | batch=1, size=1x20: 273 ± 15 ms
# ', matched '\d{1,2}\.\d{1,2} \- inference'
# batch=1, size=1x20: 273 ± 15 ms
#
# For line '1/19. MobileNet-V2
# ', matched '\d{1,2}\/\d{2}\.'
# MobileNet-V2
#
# For line '1.2 - training  | batch=50, size=224x224: 95.7 ± 38.5 ms
# ', matched '\d{1,2}\.\d{1,2} \- training'
# batch=50, size=224x224: 95.7 ± 38.5 ms
#
# For line '2/19. Inception-V3
# ', matched '\d{1,2}\/\d{2}\.'
# Inception-V3
#
# For line '2.2 - training  | batch=20, size=346x346: 142 ± 4 ms
# ', matched '\d{1,2}\.\d{1,2} \- training'
# batch=20, size=346x346: 142 ± 4 ms
#
# For line '3/19. Inception-V4
# ', matched '\d{1,2}\/\d{2}\.'
# Inception-V4
#
# For line '3.2 - training  | batch=10, size=346x346: 152 ± 3 ms
# ', matched '\d{1,2}\.\d{1,2} \- training'
# batch=10, size=346x346: 152 ± 3 ms
#
# For line '4/19. Inception-ResNet-V2
# ', matched '\d{1,2}\/\d{2}\.'
# Inception-ResNet-V2
#
# For line '4.2 - training  | batch=8, size=346x346: 163 ± 3 ms
# ', matched '\d{1,2}\.\d{1,2} \- training'
# batch=8, size=346x346: 163 ± 3 ms
#
# For line '5/19. ResNet-V2-50
# ', matched '\d{1,2}\/\d{2}\.'
# ResNet-V2-50
#
# For line '5.2 - training  | batch=10, size=346x346: 82.0 ± 1.5 ms
# ', matched '\d{1,2}\.\d{1,2} \- training'
# batch=10, size=346x346: 82.0 ± 1.5 ms
#
# For line '6/19. ResNet-V2-152
# ', matched '\d{1,2}\/\d{2}\.'
# ResNet-V2-152
#
# For line '6.2 - training  | batch=10, size=256x256: 113 ± 2 ms
# ', matched '\d{1,2}\.\d{1,2} \- training'
# batch=10, size=256x256: 113 ± 2 ms
#
# For line '7/19. VGG-16
# ', matched '\d{1,2}\/\d{2}\.'
# VGG-16
#
# For line '7.2 - training  | batch=2, size=224x224: 74.1 ± 0.6 ms
# ', matched '\d{1,2}\.\d{1,2} \- training'
# batch=2, size=224x224: 74.1 ± 0.6 ms
#
# For line '8/19. SRCNN 9-5-5
# ', matched '\d{1,2}\/\d{2}\.'
# SRCNN 9-5-5
#
# For line '8.3 - training  | batch=10, size=512x512: 162 ± 10 ms
# ', matched '\d{1,2}\.\d{1,2} \- training'
# batch=10, size=512x512: 162 ± 10 ms
#
# For line '9/19. VGG-19 Super-Res
# ', matched '\d{1,2}\/\d{2}\.'
# VGG-19 Super-Res
#
# For line '9.3 - training  | batch=10, size=224x224: 167 ± 1 ms
# ', matched '\d{1,2}\.\d{1,2} \- training'
# batch=10, size=224x224: 167 ± 1 ms
#
# For line '10/19. ResNet-SRGAN
# ', matched '\d{1,2}\/\d{2}\.'
# ResNet-SRGAN
#
# For line '10.3 - training  | batch=5, size=512x512: 108 ± 3 ms
# ', matched '\d{1,2}\.\d{1,2} \- training'
# batch=5, size=512x512: 108 ± 3 ms
#
# For line '11/19. ResNet-DPED
# ', matched '\d{1,2}\/\d{2}\.'
# ResNet-DPED
#
# For line '11.3 - training  | batch=15, size=128x128: 105.4 ± 1.0 ms
# ', matched '\d{1,2}\.\d{1,2} \- training'
# batch=15, size=128x128: 105.4 ± 1.0 ms
#
# For line '12/19. U-Net
# ', matched '\d{1,2}\/\d{2}\.'
# U-Net
#
# For line '12.3 - training  | batch=4, size=256x256: 127 ± 1 ms
# ', matched '\d{1,2}\.\d{1,2} \- training'
# batch=4, size=256x256: 127 ± 1 ms
#
# For line '13/19. Nvidia-SPADE
# ', matched '\d{1,2}\/\d{2}\.'
# Nvidia-SPADE
#
# For line '13.2 - training  | batch=1, size=128x128: 98.4 ± 1.6 ms
# ', matched '\d{1,2}\.\d{1,2} \- training'
# batch=1, size=128x128: 98.4 ± 1.6 ms
#
# For line '14/19. ICNet
# ', matched '\d{1,2}\/\d{2}\.'
# ICNet
#
# For line '14.2 - training  | batch=10, size=1024x1536: 591 ± 9 ms
# ', matched '\d{1,2}\.\d{1,2} \- training'
# batch=10, size=1024x1536: 591 ± 9 ms
#
# For line '15/19. PSPNet
# ', matched '\d{1,2}\/\d{2}\.'
# PSPNet
#
# For line '15.2 - training  | batch=1, size=512x512: 106 ± 2 ms
# ', matched '\d{1,2}\.\d{1,2} \- training'
# batch=1, size=512x512: 106 ± 2 ms
#
# For line '16/19. DeepLab
# ', matched '\d{1,2}\/\d{2}\.'
# DeepLab
#
# For line '16.2 - training  | batch=1, size=384x384: 83.4 ± 1.2 ms
# ', matched '\d{1,2}\.\d{1,2} \- training'
# batch=1, size=384x384: 83.4 ± 1.2 ms
#
# For line '17/19. Pixel-RNN
# ', matched '\d{1,2}\/\d{2}\.'
# Pixel-RNN
#
# For line '17.2 - training  | batch=10, size=64x64: 1871 ± 44 ms
# ', matched '\d{1,2}\.\d{1,2} \- training'
# batch=10, size=64x64: 1871 ± 44 ms
#
# For line '18/19. LSTM-Sentiment
# ', matched '\d{1,2}\/\d{2}\.'
# LSTM-Sentiment
#
# For line '18.2 - training  | batch=10, size=1024x300: 1046 ± 50 ms
# ', matched '\d{1,2}\.\d{1,2} \- training'
# batch=10, size=1024x300: 1046 ± 50 ms
#
# For line '19/19. GNMT-Translation
# ', matched '\d{1,2}\/\d{2}\.'
# GNMT-Translation
#
# For line 'Device Inference Score: 15004
# ', matched 'Device Inference Score\:'
# 15004
#
# For line 'Device Training Score: 17908
# ', matched 'Device Training Score\:'
# 17908
#
# For line 'Device AI Score: 32912
# ', matched 'Device AI Score\:'
# 32912
#
#
#
# Filename: aibenchmark-gpu-nutanix.log
# For line '*  Platform: Linux-5.3.0-28-generic-x86_64-with-Ubuntu-18.04-bionic
# ', matched '\*  Platform\:(.*)'
# Linux-5.3.0-28-generic-x86_64-with-Ubuntu-18.04-bionic
#
# For line '*  CPU: N/A
# ', matched '\*  CPU\:(.*)'
# N/A
#
# For line '*  CPU RAM: 63 GB
# ', matched '\*  CPU RAM\:(.*)'
# 63 GB
#
# For line '*  GPU/0: GRID V100D-16Q
# ', matched '\*  GPU/0\:(.*)'
# GRID V100D-16Q
#
# For line '*  GPU RAM: 12.9 GB
# ', matched '\*  GPU RAM\:(.*)'
# 12.9 GB
#
# For line '*  CUDA Version: 10.2
# ', matched '\*  CUDA Version\:(.*)'
# 10.2
#
# For line '1/19. MobileNet-V2
# ', matched '\d{1,2}\/\d{2}\.'
# MobileNet-V2
#
# For line '1.1 - inference | batch=50, size=224x224: 45.1 ± 40.1 ms
# ', matched '\d{1,2}\.\d{1,2} \- inference'
# batch=50, size=224x224: 45.1 ± 40.1 ms
#
# For line '2/19. Inception-V3
# ', matched '\d{1,2}\/\d{2}\.'
# Inception-V3
#
# For line '2.1 - inference | batch=20, size=346x346: 56.4 ± 3.2 ms
# ', matched '\d{1,2}\.\d{1,2} \- inference'
# batch=20, size=346x346: 56.4 ± 3.2 ms
#
# For line '3/19. Inception-V4
# ', matched '\d{1,2}\/\d{2}\.'
# Inception-V4
#
# For line '3.1 - inference | batch=10, size=346x346: 53.0 ± 1.1 ms
# ', matched '\d{1,2}\.\d{1,2} \- inference'
# batch=10, size=346x346: 53.0 ± 1.1 ms
#
# For line '4/19. Inception-ResNet-V2
# ', matched '\d{1,2}\/\d{2}\.'
# Inception-ResNet-V2
#
# For line '4.1 - inference | batch=10, size=346x346: 68.8 ± 1.1 ms
# ', matched '\d{1,2}\.\d{1,2} \- inference'
# batch=10, size=346x346: 68.8 ± 1.1 ms
#
# For line '5/19. ResNet-V2-50
# ', matched '\d{1,2}\/\d{2}\.'
# ResNet-V2-50
#
# For line '5.1 - inference | batch=10, size=346x346: 35.1 ± 1.4 ms
# ', matched '\d{1,2}\.\d{1,2} \- inference'
# batch=10, size=346x346: 35.1 ± 1.4 ms
#
# For line '6/19. ResNet-V2-152
# ', matched '\d{1,2}\/\d{2}\.'
# ResNet-V2-152
#
# For line '6.1 - inference | batch=10, size=256x256: 39.4 ± 0.9 ms
# ', matched '\d{1,2}\.\d{1,2} \- inference'
# batch=10, size=256x256: 39.4 ± 0.9 ms
#
# For line '7/19. VGG-16
# ', matched '\d{1,2}\/\d{2}\.'
# VGG-16
#
# For line '7.1 - inference | batch=20, size=224x224: 63.8 ± 1.1 ms
# ', matched '\d{1,2}\.\d{1,2} \- inference'
# batch=20, size=224x224: 63.8 ± 1.1 ms
#
# For line '8/19. SRCNN 9-5-5
# ', matched '\d{1,2}\/\d{2}\.'
# SRCNN 9-5-5
#
# For line '8.1 - inference | batch=10, size=512x512: 97.2 ± 0.9 ms
# ', matched '\d{1,2}\.\d{1,2} \- inference'
# batch=10, size=512x512: 97.2 ± 0.9 ms
#
# For line '8.2 - inference | batch=1, size=1536x1536: 64.8 ± 1.1 ms
# ', matched '\d{1,2}\.\d{1,2} \- inference'
# batch=1, size=1536x1536: 64.8 ± 1.1 ms
#
# For line '9/19. VGG-19 Super-Res
# ', matched '\d{1,2}\/\d{2}\.'
# VGG-19 Super-Res
#
# For line '9.1 - inference | batch=10, size=256x256: 66.9 ± 0.9 ms
# ', matched '\d{1,2}\.\d{1,2} \- inference'
# batch=10, size=256x256: 66.9 ± 0.9 ms
#
# For line '9.2 - inference | batch=1, size=1024x1024: 105 ± 1 ms
# ', matched '\d{1,2}\.\d{1,2} \- inference'
# batch=1, size=1024x1024: 105 ± 1 ms
#
# For line '10/19. ResNet-SRGAN
# ', matched '\d{1,2}\/\d{2}\.'
# ResNet-SRGAN
#
# For line '10.1 - inference | batch=10, size=512x512: 72.5 ± 1.1 ms
# ', matched '\d{1,2}\.\d{1,2} \- inference'
# batch=10, size=512x512: 72.5 ± 1.1 ms
#
# For line '10.2 - inference | batch=1, size=1536x1536: 65.9 ± 0.9 ms
# ', matched '\d{1,2}\.\d{1,2} \- inference'
# batch=1, size=1536x1536: 65.9 ± 0.9 ms
#
# For line '11/19. ResNet-DPED
# ', matched '\d{1,2}\/\d{2}\.'
# ResNet-DPED
#
# For line '11.1 - inference | batch=10, size=256x256: 68.7 ± 1.3 ms
# ', matched '\d{1,2}\.\d{1,2} \- inference'
# batch=10, size=256x256: 68.7 ± 1.3 ms
#
# For line '11.2 - inference | batch=1, size=1024x1024: 137 ± 2 ms
# ', matched '\d{1,2}\.\d{1,2} \- inference'
# batch=1, size=1024x1024: 137 ± 2 ms
#
# For line '12/19. U-Net
# ', matched '\d{1,2}\/\d{2}\.'
# U-Net
#
# For line '12.1 - inference | batch=4, size=512x512: 131 ± 2 ms
# ', matched '\d{1,2}\.\d{1,2} \- inference'
# batch=4, size=512x512: 131 ± 2 ms
#
# For line '12.2 - inference | batch=1, size=1024x1024: 130.8 ± 0.7 ms
# ', matched '\d{1,2}\.\d{1,2} \- inference'
# batch=1, size=1024x1024: 130.8 ± 0.7 ms
#
# For line '13/19. Nvidia-SPADE
# ', matched '\d{1,2}\/\d{2}\.'
# Nvidia-SPADE
#
# For line '13.1 - inference | batch=5, size=128x128: 69.6 ± 1.1 ms
# ', matched '\d{1,2}\.\d{1,2} \- inference'
# batch=5, size=128x128: 69.6 ± 1.1 ms
#
# For line '14/19. ICNet
# ', matched '\d{1,2}\/\d{2}\.'
# ICNet
#
# For line '14.1 - inference | batch=5, size=1024x1536: 199 ± 2 ms
# ', matched '\d{1,2}\.\d{1,2} \- inference'
# batch=5, size=1024x1536: 199 ± 2 ms
#
# For line '15/19. PSPNet
# ', matched '\d{1,2}\/\d{2}\.'
# PSPNet
#
# For line '15.1 - inference | batch=5, size=720x720: 271 ± 5 ms
# ', matched '\d{1,2}\.\d{1,2} \- inference'
# batch=5, size=720x720: 271 ± 5 ms
#
# For line '16/19. DeepLab
# ', matched '\d{1,2}\/\d{2}\.'
# DeepLab
#
# For line '16.1 - inference | batch=2, size=512x512: 82.4 ± 0.9 ms
# ', matched '\d{1,2}\.\d{1,2} \- inference'
# batch=2, size=512x512: 82.4 ± 0.9 ms
#
# For line '17/19. Pixel-RNN
# ', matched '\d{1,2}\/\d{2}\.'
# Pixel-RNN
#
# For line '17.1 - inference | batch=50, size=64x64: 640 ± 62 ms
# ', matched '\d{1,2}\.\d{1,2} \- inference'
# batch=50, size=64x64: 640 ± 62 ms
#
# For line '18/19. LSTM-Sentiment
# ', matched '\d{1,2}\/\d{2}\.'
# LSTM-Sentiment
#
# For line '18.1 - inference | batch=100, size=1024x300: 584 ± 16 ms
# ', matched '\d{1,2}\.\d{1,2} \- inference'
# batch=100, size=1024x300: 584 ± 16 ms
#
# For line '19/19. GNMT-Translation
# ', matched '\d{1,2}\/\d{2}\.'
# GNMT-Translation
#
# For line '19.1 - inference | batch=1, size=1x20: 146 ± 7 ms
# ', matched '\d{1,2}\.\d{1,2} \- inference'
# batch=1, size=1x20: 146 ± 7 ms
#
# For line '1/19. MobileNet-V2
# ', matched '\d{1,2}\/\d{2}\.'
# MobileNet-V2
#
# For line '1.2 - training  | batch=50, size=224x224: 102 ± 56 ms
# ', matched '\d{1,2}\.\d{1,2} \- training'
# batch=50, size=224x224: 102 ± 56 ms
#
# For line '2/19. Inception-V3
# ', matched '\d{1,2}\/\d{2}\.'
# Inception-V3
#
# For line '2.2 - training  | batch=20, size=346x346: 159 ± 1 ms
# ', matched '\d{1,2}\.\d{1,2} \- training'
# batch=20, size=346x346: 159 ± 1 ms
#
# For line '3/19. Inception-V4
# ', matched '\d{1,2}\/\d{2}\.'
# Inception-V4
#
# For line '3.2 - training  | batch=10, size=346x346: 171.9 ± 0.8 ms
# ', matched '\d{1,2}\.\d{1,2} \- training'
# batch=10, size=346x346: 171.9 ± 0.8 ms
#
# For line '4/19. Inception-ResNet-V2
# ', matched '\d{1,2}\/\d{2}\.'
# Inception-ResNet-V2
#
# For line '4.2 - training  | batch=8, size=346x346: 184.4 ± 0.9 ms
# ', matched '\d{1,2}\.\d{1,2} \- training'
# batch=8, size=346x346: 184.4 ± 0.9 ms
#
# For line '5/19. ResNet-V2-50
# ', matched '\d{1,2}\/\d{2}\.'
# ResNet-V2-50
#
# For line '5.2 - training  | batch=10, size=346x346: 88.5 ± 1.6 ms
# ', matched '\d{1,2}\.\d{1,2} \- training'
# batch=10, size=346x346: 88.5 ± 1.6 ms
#
# For line '6/19. ResNet-V2-152
# ', matched '\d{1,2}\/\d{2}\.'
# ResNet-V2-152
#
# For line '6.2 - training  | batch=10, size=256x256: 128 ± 1 ms
# ', matched '\d{1,2}\.\d{1,2} \- training'
# batch=10, size=256x256: 128 ± 1 ms
#
# For line '7/19. VGG-16
# ', matched '\d{1,2}\/\d{2}\.'
# VGG-16
#
# For line '7.2 - training  | batch=2, size=224x224: 86.1 ± 1.6 ms
# ', matched '\d{1,2}\.\d{1,2} \- training'
# batch=2, size=224x224: 86.1 ± 1.6 ms
#
# For line '8/19. SRCNN 9-5-5
# ', matched '\d{1,2}\/\d{2}\.'
# SRCNN 9-5-5
#
# For line '8.3 - training  | batch=10, size=512x512: 171 ± 15 ms
# ', matched '\d{1,2}\.\d{1,2} \- training'
# batch=10, size=512x512: 171 ± 15 ms
#
# For line '9/19. VGG-19 Super-Res
# ', matched '\d{1,2}\/\d{2}\.'
# VGG-19 Super-Res
#
# For line '9.3 - training  | batch=10, size=224x224: 179.5 ± 0.7 ms
# ', matched '\d{1,2}\.\d{1,2} \- training'
# batch=10, size=224x224: 179.5 ± 0.7 ms
#
# For line '10/19. ResNet-SRGAN
# ', matched '\d{1,2}\/\d{2}\.'
# ResNet-SRGAN
#
# For line '10.3 - training  | batch=5, size=512x512: 116 ± 2 ms
# ', matched '\d{1,2}\.\d{1,2} \- training'
# batch=5, size=512x512: 116 ± 2 ms
#
# For line '11/19. ResNet-DPED
# ', matched '\d{1,2}\/\d{2}\.'
# ResNet-DPED
#
# For line '11.3 - training  | batch=15, size=128x128: 113.1 ± 0.5 ms
# ', matched '\d{1,2}\.\d{1,2} \- training'
# batch=15, size=128x128: 113.1 ± 0.5 ms
#
# For line '12/19. U-Net
# ', matched '\d{1,2}\/\d{2}\.'
# U-Net
#
# For line '12.3 - training  | batch=4, size=256x256: 137 ± 1 ms
# ', matched '\d{1,2}\.\d{1,2} \- training'
# batch=4, size=256x256: 137 ± 1 ms
#
# For line '13/19. Nvidia-SPADE
# ', matched '\d{1,2}\/\d{2}\.'
# Nvidia-SPADE
#
# For line '13.2 - training  | batch=1, size=128x128: 108.4 ± 0.5 ms
# ', matched '\d{1,2}\.\d{1,2} \- training'
# batch=1, size=128x128: 108.4 ± 0.5 ms
#
# For line '14/19. ICNet
# ', matched '\d{1,2}\/\d{2}\.'
# ICNet
#
# For line '14.2 - training  | batch=10, size=1024x1536: 670 ± 31 ms
# ', matched '\d{1,2}\.\d{1,2} \- training'
# batch=10, size=1024x1536: 670 ± 31 ms
#
# For line '15/19. PSPNet
# ', matched '\d{1,2}\/\d{2}\.'
# PSPNet
#
# For line '15.2 - training  | batch=1, size=512x512: 110 ± 1 ms
# ', matched '\d{1,2}\.\d{1,2} \- training'
# batch=1, size=512x512: 110 ± 1 ms
#
# For line '16/19. DeepLab
# ', matched '\d{1,2}\/\d{2}\.'
# DeepLab
#
# For line '16.2 - training  | batch=1, size=384x384: 95.7 ± 1.5 ms
# ', matched '\d{1,2}\.\d{1,2} \- training'
# batch=1, size=384x384: 95.7 ± 1.5 ms
#
# For line '17/19. Pixel-RNN
# ', matched '\d{1,2}\/\d{2}\.'
# Pixel-RNN
#
# For line '17.2 - training  | batch=10, size=64x64: 1792 ± 166 ms
# ', matched '\d{1,2}\.\d{1,2} \- training'
# batch=10, size=64x64: 1792 ± 166 ms
#
# For line '18/19. LSTM-Sentiment
# ', matched '\d{1,2}\/\d{2}\.'
# LSTM-Sentiment
#
# For line '18.2 - training  | batch=10, size=1024x300: 1066 ± 90 ms
# ', matched '\d{1,2}\.\d{1,2} \- training'
# batch=10, size=1024x300: 1066 ± 90 ms
#
# For line '19/19. GNMT-Translation
# ', matched '\d{1,2}\/\d{2}\.'
# GNMT-Translation
#
# For line 'Device Inference Score: 14518
# ', matched 'Device Inference Score\:'
# 14518
#
# For line 'Device Training Score: 16482
# ', matched 'Device Training Score\:'
# 16482
#
# For line 'Device AI Score: 31000
# ', matched 'Device AI Score\:'
# 31000
#
#
#
# Filename: aibenchmark-gpu-slate15.log
# For line '*  Platform: Linux-5.4.0-42-generic-x86_64-with-Ubuntu-18.04-bionic
# ', matched '\*  Platform\:(.*)'
# Linux-5.4.0-42-generic-x86_64-with-Ubuntu-18.04-bionic
#
# For line '*  CPU: Intel(R) Core(TM) i7-9750H CPU @ 2.60GHz 12 cores
# ', matched '\*  CPU\:(.*)'
# Intel(R) Core(TM) i7-9750H CPU @ 2.60GHz 12 cores
#
# For line '*  CPU RAM: 15 GB
# ', matched '\*  CPU RAM\:(.*)'
# 15 GB
#
# For line '*  GPU/0: GeForce RTX 2070 with Max-Q Design
# ', matched '\*  GPU/0\:(.*)'
# GeForce RTX 2070 with Max-Q Design
#
# For line '*  GPU RAM: 6.9 GB
# ', matched '\*  GPU RAM\:(.*)'
# 6.9 GB
#
# For line '*  CUDA Version: 10.2
# ', matched '\*  CUDA Version\:(.*)'
# 10.2
#
# For line '1/19. MobileNet-V2
# ', matched '\d{1,2}\/\d{2}\.'
# MobileNet-V2
#
# For line '1.1 - inference | batch=50, size=224x224: 62.4 ± 64.0 ms
# ', matched '\d{1,2}\.\d{1,2} \- inference'
# batch=50, size=224x224: 62.4 ± 64.0 ms
#
# For line '2/19. Inception-V3
# ', matched '\d{1,2}\/\d{2}\.'
# Inception-V3
#
# For line '2.1 - inference | batch=20, size=346x346: 87.4 ± 2.2 ms
# ', matched '\d{1,2}\.\d{1,2} \- inference'
# batch=20, size=346x346: 87.4 ± 2.2 ms
#
# For line '3/19. Inception-V4
# ', matched '\d{1,2}\/\d{2}\.'
# Inception-V4
#
# For line '3.1 - inference | batch=10, size=346x346: 85.5 ± 1.3 ms
# ', matched '\d{1,2}\.\d{1,2} \- inference'
# batch=10, size=346x346: 85.5 ± 1.3 ms
#
# For line '4/19. Inception-ResNet-V2
# ', matched '\d{1,2}\/\d{2}\.'
# Inception-ResNet-V2
#
# For line '4.1 - inference | batch=10, size=346x346: 112.2 ± 0.8 ms
# ', matched '\d{1,2}\.\d{1,2} \- inference'
# batch=10, size=346x346: 112.2 ± 0.8 ms
#
# For line '5/19. ResNet-V2-50
# ', matched '\d{1,2}\/\d{2}\.'
# ResNet-V2-50
#
# For line '5.1 - inference | batch=10, size=346x346: 54.3 ± 1.0 ms
# ', matched '\d{1,2}\.\d{1,2} \- inference'
# batch=10, size=346x346: 54.3 ± 1.0 ms
#
# For line '6/19. ResNet-V2-152
# ', matched '\d{1,2}\/\d{2}\.'
# ResNet-V2-152
#
# For line '6.1 - inference | batch=10, size=256x256: 75.5 ± 1.1 ms
# ', matched '\d{1,2}\.\d{1,2} \- inference'
# batch=10, size=256x256: 75.5 ± 1.1 ms
#
# For line '7/19. VGG-16
# ', matched '\d{1,2}\/\d{2}\.'
# VGG-16
#
# For line '7.1 - inference | batch=20, size=224x224: 165 ± 2 ms
# ', matched '\d{1,2}\.\d{1,2} \- inference'
# batch=20, size=224x224: 165 ± 2 ms
#
# For line '8/19. SRCNN 9-5-5
# ', matched '\d{1,2}\/\d{2}\.'
# SRCNN 9-5-5
#
# For line '8.1 - inference | batch=10, size=512x512: 102 ± 6 ms
# ', matched '\d{1,2}\.\d{1,2} \- inference'
# batch=10, size=512x512: 102 ± 6 ms
#
# For line '8.2 - inference | batch=1, size=1536x1536: 110.9 ± 1.0 ms
# ', matched '\d{1,2}\.\d{1,2} \- inference'
# batch=1, size=1536x1536: 110.9 ± 1.0 ms
#
# For line '9/19. VGG-19 Super-Res
# ', matched '\d{1,2}\/\d{2}\.'
# VGG-19 Super-Res
#
# For line '9.1 - inference | batch=10, size=256x256: 187.0 ± 0.9 ms
# ', matched '\d{1,2}\.\d{1,2} \- inference'
# batch=10, size=256x256: 187.0 ± 0.9 ms
#
# For line '9.2 - inference | batch=1, size=1024x1024: 376 ± 4 ms
# ', matched '\d{1,2}\.\d{1,2} \- inference'
# batch=1, size=1024x1024: 376 ± 4 ms
#
# For line '10/19. ResNet-SRGAN
# ', matched '\d{1,2}\/\d{2}\.'
# ResNet-SRGAN
#
# For line '10.1 - inference | batch=10, size=512x512: 159.4 ± 0.8 ms
# ', matched '\d{1,2}\.\d{1,2} \- inference'
# batch=10, size=512x512: 159.4 ± 0.8 ms
#
# For line '10.2 - inference | batch=1, size=1536x1536: 145 ± 1 ms
# ', matched '\d{1,2}\.\d{1,2} \- inference'
# batch=1, size=1536x1536: 145 ± 1 ms
#
# For line '11/19. ResNet-DPED
# ', matched '\d{1,2}\/\d{2}\.'
# ResNet-DPED
#
# For line '11.1 - inference | batch=10, size=256x256: 162.9 ± 0.9 ms
# ', matched '\d{1,2}\.\d{1,2} \- inference'
# batch=10, size=256x256: 162.9 ± 0.9 ms
#
# For line '11.2 - inference | batch=1, size=1024x1024: 314 ± 1 ms
# ', matched '\d{1,2}\.\d{1,2} \- inference'
# batch=1, size=1024x1024: 314 ± 1 ms
#
# For line '12/19. U-Net
# ', matched '\d{1,2}\/\d{2}\.'
# U-Net
#
# For line '12.1 - inference | batch=4, size=512x512: 352 ± 2 ms
# ', matched '\d{1,2}\.\d{1,2} \- inference'
# batch=4, size=512x512: 352 ± 2 ms
#
# For line '12.2 - inference | batch=1, size=1024x1024: 360 ± 3 ms
# ', matched '\d{1,2}\.\d{1,2} \- inference'
# batch=1, size=1024x1024: 360 ± 3 ms
#
# For line '13/19. Nvidia-SPADE
# ', matched '\d{1,2}\/\d{2}\.'
# Nvidia-SPADE
#
# For line '13.1 - inference | batch=5, size=128x128: 157.3 ± 0.7 ms
# ', matched '\d{1,2}\.\d{1,2} \- inference'
# batch=5, size=128x128: 157.3 ± 0.7 ms
#
# For line '14/19. ICNet
# ', matched '\d{1,2}\/\d{2}\.'
# ICNet
#
# For line '14.1 - inference | batch=5, size=1024x1536: 198 ± 2 ms
# ', matched '\d{1,2}\.\d{1,2} \- inference'
# batch=5, size=1024x1536: 198 ± 2 ms
#
# For line '15/19. PSPNet
# ', matched '\d{1,2}\/\d{2}\.'
# PSPNet
#
# For line '15.1 - inference | batch=5, size=720x720: 720 ± 6 ms
# ', matched '\d{1,2}\.\d{1,2} \- inference'
# batch=5, size=720x720: 720 ± 6 ms
#
# For line '16/19. DeepLab
# ', matched '\d{1,2}\/\d{2}\.'
# DeepLab
#
# For line '16.1 - inference | batch=2, size=512x512: 187 ± 1 ms
# ', matched '\d{1,2}\.\d{1,2} \- inference'
# batch=2, size=512x512: 187 ± 1 ms
#
# For line '17/19. Pixel-RNN
# ', matched '\d{1,2}\/\d{2}\.'
# Pixel-RNN
#
# For line '17.1 - inference | batch=50, size=64x64: 469 ± 18 ms
# ', matched '\d{1,2}\.\d{1,2} \- inference'
# batch=50, size=64x64: 469 ± 18 ms
#
# For line '18/19. LSTM-Sentiment
# ', matched '\d{1,2}\/\d{2}\.'
# LSTM-Sentiment
#
# For line '18.1 - inference | batch=100, size=1024x300: 760 ± 32 ms
# ', matched '\d{1,2}\.\d{1,2} \- inference'
# batch=100, size=1024x300: 760 ± 32 ms
#
# For line '19/19. GNMT-Translation
# ', matched '\d{1,2}\/\d{2}\.'
# GNMT-Translation
#
# For line '19.1 - inference | batch=1, size=1x20: 161 ± 9 ms
# ', matched '\d{1,2}\.\d{1,2} \- inference'
# batch=1, size=1x20: 161 ± 9 ms
#
# For line '1/19. MobileNet-V2
# ', matched '\d{1,2}\/\d{2}\.'
# MobileNet-V2
#
# For line '1.2 - training  | batch=50, size=224x224: 189 ± 57 ms
# ', matched '\d{1,2}\.\d{1,2} \- training'
# batch=50, size=224x224: 189 ± 57 ms
#
# For line '2/19. Inception-V3
# ', matched '\d{1,2}\/\d{2}\.'
# Inception-V3
#
# For line '2.2 - training  | batch=20, size=346x346: 311 ± 2 ms
# ', matched '\d{1,2}\.\d{1,2} \- training'
# batch=20, size=346x346: 311 ± 2 ms
#
# For line '3/19. Inception-V4
# ', matched '\d{1,2}\/\d{2}\.'
# Inception-V4
#
# For line '3.2 - training  | batch=10, size=346x346: 329 ± 3 ms
# ', matched '\d{1,2}\.\d{1,2} \- training'
# batch=10, size=346x346: 329 ± 3 ms
#
# For line '4/19. Inception-ResNet-V2
# ', matched '\d{1,2}\/\d{2}\.'
# Inception-ResNet-V2
#
# For line '4.2 - training  | batch=8, size=346x346: 336 ± 1 ms
# ', matched '\d{1,2}\.\d{1,2} \- training'
# batch=8, size=346x346: 336 ± 1 ms
#
# For line '5/19. ResNet-V2-50
# ', matched '\d{1,2}\/\d{2}\.'
# ResNet-V2-50
#
# For line '5.2 - training  | batch=10, size=346x346: 187 ± 2 ms
# ', matched '\d{1,2}\.\d{1,2} \- training'
# batch=10, size=346x346: 187 ± 2 ms
#
# For line '6/19. ResNet-V2-152
# ', matched '\d{1,2}\/\d{2}\.'
# ResNet-V2-152
#
# For line '6.2 - training  | batch=10, size=256x256: 267 ± 2 ms
# ', matched '\d{1,2}\.\d{1,2} \- training'
# batch=10, size=256x256: 267 ± 2 ms
#
# For line '7/19. VGG-16
# ', matched '\d{1,2}\/\d{2}\.'
# VGG-16
#
# For line '7.2 - training  | batch=2, size=224x224: 306 ± 2 ms
# ', matched '\d{1,2}\.\d{1,2} \- training'
# batch=2, size=224x224: 306 ± 2 ms
#
# For line '8/19. SRCNN 9-5-5
# ', matched '\d{1,2}\/\d{2}\.'
# SRCNN 9-5-5
#
# For line '8.3 - training  | batch=10, size=512x512: 372 ± 6 ms
# ', matched '\d{1,2}\.\d{1,2} \- training'
# batch=10, size=512x512: 372 ± 6 ms
#
# For line '9/19. VGG-19 Super-Res
# ', matched '\d{1,2}\/\d{2}\.'
# VGG-19 Super-Res
#
# For line '9.3 - training  | batch=10, size=224x224: 476 ± 1 ms
# ', matched '\d{1,2}\.\d{1,2} \- training'
# batch=10, size=224x224: 476 ± 1 ms
#
# For line '10/19. ResNet-SRGAN
# ', matched '\d{1,2}\/\d{2}\.'
# ResNet-SRGAN
#
# For line '10.3 - training  | batch=5, size=512x512: 240 ± 2 ms
# ', matched '\d{1,2}\.\d{1,2} \- training'
# batch=5, size=512x512: 240 ± 2 ms
#
# For line '11/19. ResNet-DPED
# ', matched '\d{1,2}\/\d{2}\.'
# ResNet-DPED
#
# For line '11.3 - training  | batch=15, size=128x128: 259.1 ± 0.9 ms
# ', matched '\d{1,2}\.\d{1,2} \- training'
# batch=15, size=128x128: 259.1 ± 0.9 ms
#
# For line '12/19. U-Net
# ', matched '\d{1,2}\/\d{2}\.'
# U-Net
#
# For line '12.3 - training  | batch=4, size=256x256: 324.1 ± 1.0 ms
# ', matched '\d{1,2}\.\d{1,2} \- training'
# batch=4, size=256x256: 324.1 ± 1.0 ms
#
# For line '13/19. Nvidia-SPADE
# ', matched '\d{1,2}\/\d{2}\.'
# Nvidia-SPADE
#
# For line '13.2 - training  | batch=1, size=128x128: 260 ± 1 ms
# ', matched '\d{1,2}\.\d{1,2} \- training'
# batch=1, size=128x128: 260 ± 1 ms
#
# For line '14/19. ICNet
# ', matched '\d{1,2}\/\d{2}\.'
# ICNet
#
# For line '14.2 - training  | batch=10, size=1024x1536: 561 ± 9 ms
# ', matched '\d{1,2}\.\d{1,2} \- training'
# batch=10, size=1024x1536: 561 ± 9 ms
#
# For line '15/19. PSPNet
# ', matched '\d{1,2}\/\d{2}\.'
# PSPNet
#
# For line '15.2 - training  | batch=1, size=512x512: 272 ± 1 ms
# ', matched '\d{1,2}\.\d{1,2} \- training'
# batch=1, size=512x512: 272 ± 1 ms
#
# For line '16/19. DeepLab
# ', matched '\d{1,2}\/\d{2}\.'
# DeepLab
#
# For line '16.2 - training  | batch=1, size=384x384: 198 ± 1 ms
# ', matched '\d{1,2}\.\d{1,2} \- training'
# batch=1, size=384x384: 198 ± 1 ms
#
# For line '17/19. Pixel-RNN
# ', matched '\d{1,2}\/\d{2}\.'
# Pixel-RNN
#
# For line '17.2 - training  | batch=10, size=64x64: 1355 ± 46 ms
# ', matched '\d{1,2}\.\d{1,2} \- training'
# batch=10, size=64x64: 1355 ± 46 ms
#
# For line '18/19. LSTM-Sentiment
# ', matched '\d{1,2}\/\d{2}\.'
# LSTM-Sentiment
#
# For line '18.2 - training  | batch=10, size=1024x300: 972 ± 42 ms
# ', matched '\d{1,2}\.\d{1,2} \- training'
# batch=10, size=1024x300: 972 ± 42 ms
#
# For line '19/19. GNMT-Translation
# ', matched '\d{1,2}\/\d{2}\.'
# GNMT-Translation
#
# For line 'Device Inference Score: 7904
# ', matched 'Device Inference Score\:'
# 7904
#
# For line 'Device Training Score: 8744
# ', matched 'Device Training Score\:'
# 8744
#
# For line 'Device AI Score: 16648
# ', matched 'Device AI Score\:'
# 16648
#                            System  \
# 0  aibenchmark-cpu-crunchdata.log
# 1     aibenchmark-cpu-nutanix.log
# 2  aibenchmark-gpu-crunchdata.log
# 3     aibenchmark-gpu-nutanix.log
# 4     aibenchmark-gpu-slate15.log
#
#                                             PLATFORM  \
# 0  Linux-4.15.0-117-generic-x86_64-with-Ubuntu-18...
# 1  Linux-5.3.0-28-generic-x86_64-with-Ubuntu-18.0...
# 2  Linux-4.15.0-117-generic-x86_64-with-Ubuntu-18...
# 3  Linux-5.3.0-28-generic-x86_64-with-Ubuntu-18.0...
# 4  Linux-5.4.0-42-generic-x86_64-with-Ubuntu-18.0...
#
#                                            CPU_CORES    RAM  \
# 0  Intel Core Processor (Broadwell, no TSX, IBRS)...  21 GB
# 1                                                N/A  63 GB
# 2  Intel Core Processor (Broadwell, no TSX, IBRS)...  21 GB
# 3                                                N/A  63 GB
# 4  Intel(R) Core(TM) i7-9750H CPU @ 2.60GHz 12 cores  15 GB
#
#    MobileNet-V2 Inference, batch=50, size=224x224  \
# 0                                           669.0
# 1                                           370.0
# 2                                            42.7
# 3                                            45.1
# 4                                            62.4
#
#    Inception-V3 Inference, batch=20, size=346x346  \
# 0                                          1630.0
# 1                                           691.0
# 2                                            55.6
# 3                                            56.4
# 4                                            87.4
#
#    Inception-V4 Inference, batch=10, size=346x346  \
# 0                                          1694.0
# 1                                           686.0
# 2                                            48.5
# 3                                            53.0
# 4                                            85.5
#
#    Inception-ResNet-V2 Inference, batch=10, size=346x346  \
# 0                                             1830.0
# 1                                              768.0
# 2                                               60.9
# 3                                               68.8
# 4                                              112.2
#
#    ResNet-V2-50 Inference, batch=10, size=346x346  \
# 0                                          1045.0
# 1                                           495.0
# 2                                            33.5
# 3                                            35.1
# 4                                            54.3
#
#    ResNet-V2-152 Inference, batch=10, size=256x256  ...  \
# 0                                           1548.0  ...
# 1                                            653.0  ...
# 2                                             37.9  ...
# 3                                             39.4  ...
# 4                                             75.5  ...
#
#    PSPNet Training, batch=1, size=512x512  \
# 0                                  6713.0
# 1                                  3495.0
# 2                                   106.0
# 3                                   110.0
# 4                                   272.0
#
#    DeepLab Training, batch=1, size=384x384  \
# 0                                   4268.0
# 1                                   2212.0
# 2                                     83.4
# 3                                     95.7
# 4                                    198.0
#
#    Pixel-RNN Training, batch=10, size=64x64  \
# 0                                    1978.0
# 1                                    1795.0
# 2                                    1871.0
# 3                                    1792.0
# 4                                    1355.0
#
#    LSTM-Sentiment Training, batch=10, size=1024x300  Inference Score  \
# 0                                           17398.0            410.0
# 1                                            6093.0            866.0
# 2                                            1046.0          15004.0
# 3                                            1066.0          14518.0
# 4                                             972.0           7904.0
#
#    Training Score  AI Score                                 GPU  GPU_RAM  CUDA
# 0           470.0     880.0                                 NaN      NaN   NaN
# 1           786.0    1652.0                                 NaN      NaN   NaN
# 2         17908.0   32912.0                Tesla V100-SXM2-16GB  14.3 GB  10.2
# 3         16482.0   31000.0                      GRID V100D-16Q  12.9 GB  10.2
# 4          8744.0   16648.0  GeForce RTX 2070 with Max-Q Design   6.9 GB  10.2
#
# [5 rows x 52 columns]

# %%
# df = df.drop(['PLATFORM','CPU_CORES','RAM','GPU','GPU_RAM','CUDA'],axis=1)
df.to_csv("results.csv", index=False)
# ax = df.plot.bar(x=[0],y=['MobileNet-V2 Inference, batch=50, size=224x224'])
# type(df['MobileNet-V2 Inference, batch=50, size=224x224'][0])
